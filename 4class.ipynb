# %%
from keras.models import load_model
model = load_model('/content/45-classifer.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
from keras.preprocessing import image

# %%
img = image.load_img('/content/j10.jpg',target_size = (64,64))

# %%
from keras.preprocessing.image import  img_to_array
import numpy as np

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
ig=ImageDataGenerator(rescale = 1/2.55)
img_array = img_to_array(img)
img_array = np.expand_dims(img_array,axis = 0)
newimg = ig.flow(img_array)

# %%
pred = model.predict(newimg)
print("tulip")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# tulip

# %%
pred
# Out:
# array([[0., 1., 0.]], dtype=float32)

# %%
list(pred[0]).index(max(pred[0]))
# Out:
# 1

# %%
pred = model.predict(newimg)
print("tulip" if pred[0][0]>0.5 else "lilles")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# lilles
